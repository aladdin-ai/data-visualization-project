# %%
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':[25,25]} , font_scale = 1.5 )

# %%
cops = pd.read_csv("911.csv - 911.csv.csv")
cops
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 115206  40.265484 -75.293554
# 115207  40.131681 -75.389806
# 115208  40.186753 -75.143373
# 115209  40.155928 -75.141169
# 115210  40.147850 -75.333684
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 115206  WERNER RD & ORVILLA RD;  HATFIELD TOWNSHIP; St...  19440.0
# ...

# %%
cops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115211 entries, 0 to 115210
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   lat          115211 non-null  float64
#  1   lng          115211 non-null  float64
#  2   desc         115211 non-null  object
#  3   zip          100789 non-null  float64
#  4   title        115211 non-null  object
#  5   timeStamp    115211 non-null  object
#  6   twp          115177 non-null  object
#  7   addr         115211 non-null  object
#  8   e            115211 non-null  int64
#  9   Reason       115211 non-null  object
#  10  hour         115211 non-null  int64
#  11  month        115211 non-null  int64
#  12  day of week  115211 non-null  object
#  13  Year         115211 non-null  int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 12.3+ MB

# %% [markdown]
# # NUMERICAL UNIVARIATE PLOTS
# =========================================================

# %%
sns.displot(cops["hour"],color = "m",kde=True)

# %% [markdown]
# ### most calls between 8am : 8pm

# %%
sns.displot(cops["month"] , color = "m" , kde = True)

# %% [markdown]
# ### most calls in January then July
# ### In October & November there are not many calls
# ### We can say that calls in the past three months are few compared to those before

# %%
sns.displot(cops["Year"] , color = "m" , kde = True)

# %% [markdown]
# ### No calls in 2015 compared to 2016, Almost all problems occurred in 2016

# %% [markdown]
# # CATEGORICAL UNIVARIATE PLOTS
# =========================================================

# %%
sns.countplot(data = cops , y = "twp" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='count', ylabel='twp'>

# %% [markdown]
# ### Lower Merion is the most connected to 911 then Abington & Norristown are close in number
# ### Least contacted countries, in order: Lehigh County, Phila County, Green Lane

# %%
sns.countplot(data = cops , y = "twp" , palette = "icefire" , hue = "Reason")
# Out:
# <AxesSubplot:xlabel='count', ylabel='twp'>

# %% [markdown]
# ### Norristown is the most town has a EMS problem
# ### Lower Merion is the most town has a traffic problem and fire problem
# ### there are no calls from Lehigh County except EMS calls

# %%
sns.countplot(data = cops , x = "Reason" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='Reason', ylabel='count'>

# %% [markdown]
# ### there are more than 50000 calls due to EMS and this is the most calls
# ### fire calls are the least one

# %%
sns.countplot(data = cops , x = "Reason" , palette = "icefire" , hue = "day of week")
# Out:
# <AxesSubplot:xlabel='Reason', ylabel='count'>

# %% [markdown]
# ### Close fire results
# ### Fri is the most day that EMS problems happen
# ### Tue & Wed are the most days that traffic problems happen
# ### Sun is the least day there were problems

# %%
sns.countplot(data = cops , x = "hour" , palette = "icefire" , hue = "Reason")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='count'>

# %% [markdown]
# ### most of EMS calls happen at between 9am : 2pm
# ### most of traffic calls happen at between 12pm : 6pm
# ### most of fire calls happen at between 8am : 8pm

# %%
sns.countplot(data = cops , x = "month" , palette = "icefire" , hue = "Reason")
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %% [markdown]
# ### EMS data are close
# ### most of EMS calls happen in January, July, August
# ### most of traffic calls in January
# ### fire data are close
# ### most of fire calls happen in January, July, August

# %%
sns.countplot(data = cops , x = "Year" , palette = "icefire" , hue = "Reason")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %% [markdown]
# ### EMS the most problem in 2015,2016
# ### fire is the least problem in 2015,2016

# %%
sns.countplot(data = cops , x = "day of week" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='day of week', ylabel='count'>

# %% [markdown]
# ### Most of the days are similar in the number of calls
# ### Fri, Tue, Wed in the first place
# ### Sun is the least one
