# %%
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':[10,10]} , font_scale = 1.5 )

# %%
titanic = pd.read_csv("titanic.csv - titanic.csv.csv")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %% [markdown]
# ## the above syntax to know and sure each data categorical or numerical

# %% [markdown]
# # NUMERICAL UNIVARIATE PLOTS
# =========================================================

# %%
titanic["survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
sns.displot(titanic["age"],color="m")

# %% [markdown]
# ## The average age of the ship is between 20:40 years old
# ## babies more than oldmen

# %%
sns.kdeplot(titanic["survived"],color="m",shade = True)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='Density'>

# %% [markdown]
# ## There is no new comment

# %%
sns.kdeplot(titanic["age"],color="m",shade = True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ## There is no new comment

# %%
sns.kdeplot(titanic["fare"],color="m",shade = True)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %% [markdown]
# ## most people in titanic were boor
# ## a little bit rich people paid 500

# %% [markdown]
# # ==========================================================

# %% [markdown]
# # NUMERICAL BIVARIATE PLOTS
#
# =========================================================

# %%
sns.jointplot(data = titanic , x = "age" , y = "fare", color = "m")

# %% [markdown]
# ## the two odd persons that payed 500 is between 35 years old
# ## most poor people are the young men (between 20 and 40) normal condition

# %%
sns.jointplot(data = titanic , x = "age" , y = "fare", color = "m", hue = "survived")

# %% [markdown]
# ## most dead people were poor   :(
# ## few people who payed more than 500 survived

# %%
sns.jointplot(data = titanic , x = "age" , y = "fare", color = "m", hue = "alive")

# %% [markdown]
# ## most dead people from poverty region

# %%
sns.jointplot(data = titanic , x = "age" , y = "fare", color = "m", hue = "alone")

# %% [markdown]
# # =========================================
# # CATEGORICAL UNIVARIATE PLOTS
# =========================================================

# %%
sns.countplot(data = titanic , x = "sex" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## The number of women is nearly half the number of men on the ship

# %%
sns.countplot(data = titanic , x = "sex" , palette = "icefire", hue="who")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## female and male babies number are nearly the same

# %%
sns.countplot(data = titanic , x = "sex" , palette = "icefire", hue="class")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## males are the most poverty in the ship

# %%
sns.countplot(data = titanic , x = "sex" , palette = "icefire", hue="embark_town")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## males from Southampton are the most in titanic
# ## Queenstown passengers sex are almost the same number

# %%
sns.countplot(data = titanic , x = "sex" , palette = "icefire", hue="alive")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## most not survived passengers from males
# ## most survived passengers from females

# %%
sns.countplot(data = titanic , x = "sex" , palette = "icefire", hue="alone")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## most alone passengers from males more than 400 passenger
# ## most not alone passengers from females

# %%
sns.countplot(data = titanic , x = "class" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# ## third-class people is the most in the ship normal condition (boor people)
# ## first and the second class is nearly at the same level

# %%
sns.countplot(data = titanic , x = "class" , palette = "icefire", hue = "embark_town")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# ## most rich people from Cherbourg
# ## people from Southampton are the most poverty
# ## nearly no one rich from Queenstown

# %%
sns.countplot(data = titanic , x = "class" , palette = "icefire", hue = "alive")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# ## first class passenger is the most people that be alive
# ## third class passenger is the most people that not survived

# %%
sns.countplot(data = titanic , x = "class" , palette = "icefire", hue = "alone")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %% [markdown]
# ## most of third class are alone in the trip
# ## first and second classes are approximately the same by alone trip

# %%
sns.countplot(data = titanic , x = "who" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='who', ylabel='count'>

# %% [markdown]
# ## most people in the ship are men then woman then child

# %%
sns.countplot(data = titanic , x = "embark_town" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='count'>

# %% [markdown]
# ## a huge number of people are came from Southampton
# ## some people in the ship from Cherbourg and queenstown

# %%
sns.countplot(data = titanic , x = "alive" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='alive', ylabel='count'>

# %% [markdown]
# ## most people are dead but on the other way a lot of people survived, I dont think that

# %%
sns.countplot(data = titanic , x = "alone" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='alone', ylabel='count'>

# %% [markdown]
# ## most people are alone but on the other way a lot of people with there family

# %% [markdown]
# # =========================================
# # CATEGORICAL BIVARIATE PLOTS
# =========================================================

# %%
sns.swarmplot(data = titanic , x = "sex" , y = "age" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# ## there are males older than females in the ship
# ## male babies more than female babies
# ## age between 20:40 density of males is more than females

# %%
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
sns.stripplot(data = titanic , x = "sex" , y = "fare" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %% [markdown]
# ## density of poor males are more than density of poor females
# ## density of rich females are more than density of rich males

# %%
sns.boxplot(data = titanic , x = "class" , y = "age" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# ## no odd conditions in first class
# ## no one rich (paid first class) above 75 years old except first class (first class has the oldest age of all classes)

# %%
sns.swarmplot(data = titanic , x = "class" , y = "age" , palette = "icefire" , hue = "survived",dodge = True)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# ## the rich man that in first class and 80 years old survived
# ## alot of babies in first class not survived, babies survived in second and third class
# ## most passengers survived at first class between 30:40 years old
# ## most people who not survived in third class

# %%
sns.swarmplot(data = titanic , x = "class" , y = "age" , palette = "icefire" , hue = "alone" , dodge = True)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# ## the rich man that in first class and 80 years old was alone
# ## most people were alone in the third class between 20:30 years old

# %%
sns.stripplot(data = titanic , x = "class" , y = "age" , palette = "icefire" , hue = "embark_town" , dodge = True)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# ## most people from Queenstown from third class
# ## the rich man that in first class and 80 years old was from Southampton
# ## most people from Southampton from third class

# %%
sns.stripplot(data = titanic , x = "class" , y = "age" , palette = "icefire" , hue = "who" , dodge = True)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# ## most childs were from third class and a few from first class
# ## most woman were from first class

# %%
sns.boxplot(data = titanic , x = "who" , y = "age" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %% [markdown]
# ## men have an odd ages (high ages) like 80,70

# %%
sns.violinplot(data = titanic , x = "who" , y = "age" , palette = "icefire", hue = "survived" , dodge = True)
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
sns.violinplot(data = titanic , x = "who" , y = "age" , palette = "icefire", hue = "alone" , dodge = True)
# Out:
# <AxesSubplot:xlabel='who', ylabel='age'>

# %%
sns.boxplot(data = titanic , x = "embark_town" , y = "age" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='age'>

# %%
sns.swarmplot(data = titanic , x = "embark_town" , y = "age" , palette = "icefire", hue = "survived" , dodge = True)
# Out:
# <AxesSubplot:xlabel='embark_town', ylabel='age'>

# %% [markdown]
# ## most survived and not survived passengers are from Southampton
# ## there is a few passengers survived from Queenstown

# %%
sns.boxplot(data = titanic , x = "alive" , y = "age" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='alive', ylabel='age'>

# %%
sns.boxplot(data = titanic , x = "alone" , y = "age" , palette = "icefire")
# Out:
# <AxesSubplot:xlabel='alone', ylabel='age'>
